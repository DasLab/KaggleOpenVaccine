# %%
import pandas as pd
import numpy as np
import sys
from xgboost import XGBRegressor
import csv
from sklearn.metrics import r2_score

# %%
def encode_input(df, window_size=1, pad=0, no_onehot=False, seq=True, struct=True):
    '''Creat input/output for regression model for predicting structure probing data.
    Inputs:
    
    dataframe (in EternaBench RDAT format)
    window_size: size of window (in one direction). so window_size=1 is a total window size of 3
    pad: number of nucleotides at start to not include
    seq (bool): include sequence encoding
    struct (bool): include bpRNA structure encoding
    
    Outputs:
    Input array (n_samples x n_features): array of windowed input features
    feature_names (list, length = kernel x window): feature names, i.e. `S_-12`
    
    '''    
    inpts = []

    feature_kernel=[]
    if seq:
        feature_kernel.extend(['A','U','G','C'])
    if struct:
        feature_kernel.extend(['H','E','I','M','B','S', 'X'])

    feature_names = ['%s_%d' % (k, val) for val in range(-1*window_size, window_size+1) for k in feature_kernel]
    
    for i, row in df.iterrows():
        length = len(row['sequence'])
        arr = np.zeros([length,len(feature_kernel)])
        
        for index in range(length):
            ctr=0

            #encode sequence
            if seq:
                
                for char in ['A','U','G','C']:
                    if row['sequence'][index]==char:
                        arr[index,ctr]+=1
                    ctr+=1

            if struct:
                for char in ['H','E','I','M','B','S', 'X']:
                    if row['bpRNA_string'][index]==char:
                        arr[index,ctr]+=1
                    ctr+=1

        # add zero padding to the side

        padded_arr = np.vstack([np.zeros([window_size,len(feature_kernel)]), arr, np.zeros([window_size,len(feature_kernel)])])

        for index in range(length):
            new_index = index+window_size-pad
            tmp = padded_arr[new_index-window_size:new_index+window_size+1]
            inpts.append(tmp.flatten())
            
    return np.array(inpts), feature_names

# %%
reg = XGBRegressor(n_estimators=8200, tree_method='hist', learning_rate=0.005, max_depth=7, subsample=0.8, colsample_bytree=0.9, reg_alpha=0.005)

# %%
reg.load_model('../../model_files/bt_xgb/bt_xgb.model')

# %%
OpenVaccineRound6_3 = pd.read_csv('../../data/Round6_3/featurized_11132020.csv')
OpenVaccineRound6_3.head()
# Out:
#          id                                              title        name  \
# 0  10416963                                   whbob_DEG2:154.6       whbob
# 1  10416937   Astromod 1 - Jieux - OpenVaccine NanoLucifera...       Jieux
# 2  10416485                                    lowest deg ever   JPS838898
# 3  10416474                                    most brachiness   JPS838898
# 4  10416284                         Low Nat/Target Delta Seq 5   cynwulf28
#
#                                             sequence       CAI  GC content  \
# 0  AUGGCUGUCUACCCUUAUGACGUUCCCGACUACGCCGGGUACCCGU...  0.746236   57.648953
# 1  AUGGCCGUCUACCCCUACGACGUGCCCGACUACGCCGGCUACCCCU...  0.864164   57.648953
# 2  AUGGCCGUGUAUCCGUACGACGUGCCCGACUACGCGGGCUACCCGU...  0.783010   59.581320
# 3  AUGGCCGUUUACCCGUACGACGUGCCCGACUAUGCGGGGUAUCCGU...  0.776447   61.513688
# 4  AUGGCCGUUUACCCAUACGAUGUCCCUGAUUAUGCGGGCUACCCCU...  0.753577   50.402576
#
#    SUP vienna  SUP first 14 vienna  SUP first 30 vienna  \
# 0  134.176202             7.184849            11.657951
# 1  200.428832             6.543862            14.936440
# 2  123.072708             4.039793             7.352624
# 3  188.767027             2.615163             5.624280
# 4  250.485039             5.951110            10.270973
#
#                                      punp_vec vienna  ...  \
# 0  [9.88843733e-01 9.83592990e-01 9.70270735e-01 ...  ...
# 1  [9.98147497e-01 9.80697218e-01 2.05755336e-02 ...  ...
# 2  [9.57059994e-01 9.53300649e-01 9.68004883e-01 ...  ...
# 3  [8.21712061e-01 7.10491191e-01 4.83057551e-01 ...  ...
# 4  [9.99520986e-01 9.14321957e-01 9.26839517e-01 ...  ...
#
#                                MFE Struct EternaFold  \
# 0  .....((((((..((((.(((((.((((.......)))).)).(((...
# 1  ..(((((((.........)))).))).......(((((((.(((((...
# 2  ...((((.((((((((.((.(((((((((..(((((((((.(((((...
# 3  ...(((((((((((((((((((.(((((......(((((((((......
# 4  ...((((((...(((((....(((((((....(((((((.(((((....
#
#                                         bprna_string  \
# 0  EEEEESSSSSSIISSSSISSSSSISSSSHHHHHHHSSSSISSMSSS...
# 1  EESSSSSSSHHHHHHHHHSSSSBSSSEEEEEEESSSSSSSMSSSSS...
# 2  EEESSSSBSSSSSSSSISSMSSSSSSSSSIISSSSSSSSSBSSSSS...
# 3  EEESSSSSSSSSSSSSSSSSSSISSSSSIIIIIISSSSSSSSSHHH...
# 4  EEESSSSSSBBBSSSSSIIIISSSSSSSMMMMSSSSSSSBSSSSSM...
#
#                                         degscore_vec  degscore  MLD  \
# 0  [ 0.634  0.475  0.625  0.401  0.457  0.042  0....   153.777  232
# 1  [ 0.747  0.393  0.36   0.242 -0.1    0.11   0....   179.135  114
# 2  [ 0.697  0.328  0.501  0.154 -0.063 -0.026  0....   144.103  180
# 3  [ 7.25000000e-01  3.49000000e-01  4.98000000e-...   167.348  104
# 4  [ 7.620e-01  3.870e-01  4.990e-01  1.340e-01 -...   211.577   88
#
#    n_hairpins n_3WJs n_4WJs n_5WJs_up  hp_3WJ_ratio
# 0          14      8      2         0      1.750000
# 1          14      6      1         1      2.333333
# 2          16      7      2         1      2.285714
# 3          21      1      2         3     20.999979
# 4          15      4      2         1      3.749999
#
# [5 rows x 26 columns]

# %%
OpenVaccineRound6_3.columns
# Out:
# Index(['id', 'title', 'name', 'sequence', 'CAI', 'GC content', 'SUP vienna',
#        'SUP first 14 vienna', 'SUP first 30 vienna', 'punp_vec vienna',
#        'mean bp prox vienna', 'SUP eternafold', 'SUP first 14 eternafold',
#        'SUP first 30 eternafold', 'punp_vec eternafold',
#        'mean bp prox eternafold', 'MFE Struct EternaFold', 'bprna_string',
#        'degscore_vec', 'degscore', 'MLD', 'n_hairpins', 'n_3WJs', 'n_4WJs',
#        'n_5WJs_up', 'hp_3WJ_ratio'],
#       dtype='object')

# %%
OpenVaccineRound6_3.shape
# Out:
# (476, 26)

# %%
OpenVaccineRound6_3['bpRNA_string'] = OpenVaccineRound6_3['bprna_string']

# %%
# %%time
encodings_6 = []
for jj in range(476):
    encoding, feature_names = encode_input(OpenVaccineRound6_3.iloc[[jj]], window_size=20)
    encodings_6.append(encoding)
# Out:
# CPU times: user 42.4 s, sys: 293 ms, total: 42.7 s
# Wall time: 42.7 s

# %%
# %%time
preds_476 = []
for jj in range(476):
    preds_476.append(list(reg.predict(encodings_6[jj])))
# Out:
# CPU times: user 9min 39s, sys: 21.9 s, total: 10min 1s
# Wall time: 15.3 s

# %%
with open("deg_1day_pH10_476_preds_1.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(preds_476)

# %%
sum_476 = [sum(preds_476[j]) for j in range(476)]

# %%
deg_1day_pH10_476_preds_2 = pd.DataFrame(data=preds_476, columns=[f'col_{i}' for i in range(621)])
deg_1day_pH10_476_preds_2.head()
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0  0.978584  0.252353  0.403427  0.352932  0.528773  0.140609  0.619143
# 1  1.366874  0.467512  0.293191  0.292110  0.238905  0.162171  0.700368
# 2  1.426526  0.237352  0.420734  0.195684  0.103811  0.133013  0.859086
# 3  1.506381  0.201753  0.408374  0.154038  0.028042  0.088541  0.770943
# 4  1.426890  0.240958  0.433370  0.181022  0.059333  0.114806  1.096572
#
#       col_7     col_8     col_9  ...   col_611   col_612   col_613   col_614  \
# 0  0.245690  0.521728  0.180509  ...  0.402946  0.670259  0.119502  0.273410
# 1  0.258512  0.849204  0.427986  ...  0.334246  0.457866  0.032686  0.173055
# 2  0.544813  1.003162  0.234966  ...  0.275812  0.383973  0.067450  0.224177
# 3  0.847469  0.612494  0.231071  ...  0.273679  0.559544  0.044410  0.310128
# 4  1.375676  1.258920  0.971926  ...  0.366255  0.466999  0.020209  0.221892
#
#     col_615   col_616   col_617   col_618   col_619   col_620
# 0  0.173431  0.196586  0.590055  0.164320  0.463797  0.609004
# 1  0.251780  0.205398  0.584349  0.327054  0.707355  0.666594
# 2  0.194397  0.265146  1.099415  0.414379  0.763133  0.617453
# 3  0.201316  0.257605  0.803986  0.197876  0.742298  0.675877
# 4  0.132263  0.217624  1.154330  0.890833  0.608111  0.684105
#
# [5 rows x 621 columns]

# %%
deg_1day_pH10_476_preds_2['id'] = OpenVaccineRound6_3['id']
deg_1day_pH10_476_preds_2['sequence'] = OpenVaccineRound6_3['sequence']
deg_1day_pH10_476_preds_2['bprna_string'] = OpenVaccineRound6_3['bprna_string']
deg_1day_pH10_476_preds_2['BT_sum'] = sum_476
deg_1day_pH10_476_preds_2.head()
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0  0.978584  0.252353  0.403427  0.352932  0.528773  0.140609  0.619143
# 1  1.366874  0.467512  0.293191  0.292110  0.238905  0.162171  0.700368
# 2  1.426526  0.237352  0.420734  0.195684  0.103811  0.133013  0.859086
# 3  1.506381  0.201753  0.408374  0.154038  0.028042  0.088541  0.770943
# 4  1.426890  0.240958  0.433370  0.181022  0.059333  0.114806  1.096572
#
#       col_7     col_8     col_9  ...   col_615   col_616   col_617   col_618  \
# 0  0.245690  0.521728  0.180509  ...  0.173431  0.196586  0.590055  0.164320
# 1  0.258512  0.849204  0.427986  ...  0.251780  0.205398  0.584349  0.327054
# 2  0.544813  1.003162  0.234966  ...  0.194397  0.265146  1.099415  0.414379
# 3  0.847469  0.612494  0.231071  ...  0.201316  0.257605  0.803986  0.197876
# 4  1.375676  1.258920  0.971926  ...  0.132263  0.217624  1.154330  0.890833
#
#     col_619   col_620        id  \
# 0  0.463797  0.609004  10416963
# 1  0.707355  0.666594  10416937
# 2  0.763133  0.617453  10416485
# 3  0.742298  0.675877  10416474
# 4  0.608111  0.684105  10416284
#
#                                             sequence  \
# 0  AUGGCUGUCUACCCUUAUGACGUUCCCGACUACGCCGGGUACCCGU...
# 1  AUGGCCGUCUACCCCUACGACGUGCCCGACUACGCCGGCUACCCCU...
# 2  AUGGCCGUGUAUCCGUACGACGUGCCCGACUACGCGGGCUACCCGU...
# 3  AUGGCCGUUUACCCGUACGACGUGCCCGACUAUGCGGGGUAUCCGU...
# 4  AUGGCCGUUUACCCAUACGAUGUCCCUGAUUAUGCGGGCUACCCCU...
#
#                                         bprna_string      BT_sum
# 0  EEEEESSSSSSIISSSSISSSSSISSSSHHHHHHHSSSSISSMSSS...  203.162044
# 1  EESSSSSSSHHHHHHHHHSSSSBSSSEEEEEEESSSSSSSMSSSSS...  246.027418
# 2  EEESSSSBSSSSSSSSISSMSSSSSSSSSIISSSSSSSSSBSSSSS...  197.382192
# 3  EEESSSSSSSSSSSSSSSSSSSISSSSSIIIIIISSSSSSSSSHHH...  227.825743
# 4  EEESSSSSSBBBSSSSSIIIISSSSSSSMMMMSSSSSSSBSSSSSM...  304.010493
#
# [5 rows x 625 columns]

# %%
deg_1day_pH10_476_preds_2.to_csv('deg_1day_pH10_476_preds_2.csv', index=False)

# %%
for i in range(476):
    print(sum_476[i])
# Out:
# 203.16204407811165
# 246.02741834521294
# 197.38219156861305
# 227.82574316859245
# 304.0104932487011
# 305.7988051176071
# 216.26331394910812
# 213.59781569242477
# 221.80225601792336
# 207.6509049832821
# 214.9006531238556
# 219.70916339755058
# 213.13289752602577
# 196.4035760164261
# 302.8732439875603
# 197.7642703652382
# 195.84690064191818
# 196.571280002594
# 241.44171050190926
# 246.54347160458565
# 197.3058130145073
# 208.70965790748596
# 316.6518704891205
# 318.4254606962204
# 318.0910930633545
# 221.99507722258568
# 316.1214688718319
# 248.97442588210106
# 303.2032385468483
# 248.86338204145432
# 231.57696130871773
# 248.29990455508232
# 247.90277150273323
# 251.6276678442955
# 224.95098316669464
# 224.9047634601593
# 225.21095395088196
# 223.14673948287964
# 218.99373188614845
# 199.98512452840805
# 196.65731370449066
# 225.61103335022926
# 227.1113322675228
# 262.5455836057663
# 195.4520898759365
# 204.49802672863007
# 202.62537956237793
# 265.9784489274025
# 200.91708454489708
# 202.55507707595825
# 259.59362986683846
# 302.8652520775795
# 223.66645056009293
# 213.93165132403374
# 220.6942323744297
# 221.15323886275291
# 207.48424834012985
# 207.12279418110847
# 237.08938190340996
# 236.282386302948
# 242.0113107562065
# 242.7311214506626
# 245.11937847733498
# 210.0171156525612
# 241.07072153687477
# 240.65552932024002
# 241.25677052140236
# 241.03247144818306
# 240.84591826796532
# 240.2810115814209
# 240.1939891576767
# 241.2392095029354
# 240.90673157572746
# 241.95851883292198
# 242.8247720003128
# 242.7418449819088
# 240.73936986923218
# 240.90781939029694
# 240.51340344548225
# 232.84511759877205
# 234.25425922870636
# 232.12365001440048
# 232.34223181009293
# 230.34372568130493
# 220.2111177444458
# 216.47475317120552
# 203.16711828112602
# 219.63160073757172
# 220.82259851694107
# 276.72685673832893
# 198.05027028918266
# 278.28047731518745
# 260.4904164969921
# 246.13724184036255
# 248.71029859781265
# 222.55347284674644
# 231.22430473566055
# 246.76018780469894
# 234.11132979393005
# 239.29086938500404
# 257.4778255224228
# 218.13975778222084
# 217.9663755595684
# 212.83035469055176
# 207.07281032204628
# 207.8575758934021
# 205.8432606458664
# 209.62300184369087
# 206.79082468152046
# 211.8843392431736
# 203.49903506040573
# 216.63213336467743
# 197.2625773847103
# 212.35210740566254
# 197.64119511842728
# 210.6425887644291
# 210.50675532221794
# 201.6167149245739
# 264.1608439683914
# 241.4170319736004
# 204.15864148736
# 220.0661083161831
# 292.4878309369087
# 231.29344603419304
# 218.12870863080025
# 238.63744086027145
# 218.3977166712284
# 199.12934324145317
# 208.3785902261734
# 275.07025867700577
# 203.37139198184013
# 212.9324226975441
# 221.0456267297268
# 245.52018722891808
# 272.75719034671783
# 198.6979334950447
# 205.7466872036457
# 225.92964735627174
# 220.20194151997566
# 197.29509988427162
# 206.48091134428978
# 216.77302223443985
# 220.71987852454185
# 221.00970593094826
# 227.19651320576668
# 234.5331992805004
# 199.07070285081863
# 197.9839772284031
# 265.69117560982704
# 207.4210428893566
# 198.19347089529037
# 197.81395336985588
# 199.93447422981262
# 199.45377829670906
# 221.91705667972565
# 223.3809871673584
# 232.73652318120003
# 222.7563220858574
# 225.72300484776497
# 225.62829491496086
# 231.0133000612259
# 216.15321192145348
# 211.76630610227585
# 208.92072305083275
# 240.61116048693657
# 208.26906695961952
# 211.8212021291256
# 211.41337403655052
# 216.32232037186623
# 224.60801714658737
# 296.20002496242523
# 319.5093322992325
# 217.63359728455544
# 262.7572318315506
# 194.08997055888176
# 196.49778231978416
# 248.0874040722847
# 248.39146503806114
# 226.51890924572945
# 262.03139904141426
# 224.15215587615967
# 212.52542957663536
# 225.90508779883385
# 231.3963713645935
# 221.6190817952156
# 217.9119638800621
# 248.52420741319656
# 253.88286620378494
# 250.63324138522148
# 220.30218997597694
# 220.0110039114952
# 219.6724869608879
# 220.40312099456787
# 220.87432339787483
# 220.68580719828606
# 206.92359620332718
# 257.43025955557823
# 263.66948351264
# 226.17854171991348
# 223.5220776796341
# 226.18253642320633
# 217.0809541940689
# 292.40674564242363
# 295.93811267614365
# 306.1838407814503
# 302.3916954398155
# 280.73920917510986
# 261.1818353533745
# 241.89889320731163
# 222.19107046723366
# 222.08414992690086
# 226.89013168215752
# 226.2404064834118
# 226.01493605971336
# 225.78879326581955
# 211.0932204425335
# 225.87349173426628
# 226.44887924194336
# 227.42825344204903
# 229.15955382585526
# 232.15267032384872
# 234.38744965195656
# 238.79133754968643
# 238.72956830263138
# 242.26026791334152
# 245.30505177378654
# 250.2160367667675
# 250.6110488474369
# 253.6655015051365
# 254.07460778951645
# 254.03785786032677
# 253.82052993774414
# 253.88669583201408
# 254.5931082367897
# 255.87396118044853
# 256.6761564910412
# 260.124927431345
# 260.861800968647
# 257.87152057886124
# 258.39381098747253
# 258.4446552693844
# 259.7046360373497
# 263.9297435581684
# 263.25670325756073
# 266.9106675684452
# 264.7427740097046
# 266.3475071489811
# 269.5605776309967
# 273.4639137983322
# 273.87188267707825
# 273.8577119112015
# 274.2927797138691
# 283.25431567430496
# 284.5542203783989
# 278.638512134552
# 286.298355281353
# 279.97104927897453
# 282.58846536278725
# 254.49886286258698
# 282.7179506123066
# 286.3396496772766
# 292.2631920874119
# 283.28311109542847
# 284.2984210550785
# 284.99007365107536
# 285.3849772810936
# 287.32841297984123
# 288.44684612751007
# 289.90526750683784
# 293.48022481799126
# 296.9611195027828
# 308.01399821043015
# 307.8483363389969
# 309.1719509065151
# 309.2592107653618
# 309.86565735936165
# 310.04112073779106
# 320.58404687047005
# 318.6209429502487
# 217.71001321077347
# 272.9067951142788
# 263.3617234826088
# 302.4576373696327
# 220.6339380145073
# 224.0775652229786
# 228.10592448711395
# 224.94855916500092
# 195.0507996082306
# 204.97248789668083
# 210.5278993844986
# 195.20337760448456
# 226.66936221718788
# 196.96291002631187
# 226.77044475078583
# 220.46643376350403
# 195.57534903287888
# 222.87791022658348
# 227.27268308401108
# 265.79938352108
# 261.8674811720848
# 349.86785635352135
# 195.61540135741234
# 221.236850887537
# 230.4311546087265
# 232.7963274717331
# 195.94834879040718
# 236.08815002441406
# 199.50882655382156
# 200.4416449368
# 197.28856229782104
# 198.9816935658455
# 201.45721596479416
# 262.96200200915337
# 261.421418428421
# 251.63909554481506
# 261.76624116301537
# 250.6532572209835
# 251.7459322810173
# 223.58005210757256
# 235.52239432930946
# 222.06546717882156
# 226.77839449048042
# 215.39177709817886
# 222.3293670117855
# 233.35774970054626
# 214.94772440195084
# 236.59853160381317
# 232.0493113398552
# 233.7244285941124
# 239.22019067406654
# 308.8652329444885
# 330.60133162140846
# 334.4243007302284
# 321.92194908857346
# 210.85195261240005
# 244.23951455950737
# 251.83655789494514
# 222.30657428503036
# 297.2250771522522
# 304.3790045976639
# 274.1227114498615
# 318.92635878920555
# 343.50082528591156
# 215.99102848768234
# 211.31760278344154
# 205.79793265461922
# 226.51758325099945
# 230.67911714315414
# 226.63394218683243
# 260.4155873656273
# 312.7726759314537
# 297.09534937143326
# 303.13590133190155
# 303.2966867685318
# 289.65489038825035
# 307.52870029211044
# 304.0988432765007
# 304.4104302227497
# 307.29848605394363
# 305.7324928343296
# 312.79374101758003
# 320.9210871756077
# 317.3716943860054
# 309.98027661442757
# 310.320147305727
# 301.8019210398197
# 319.67875120043755
# 308.18343406915665
# 310.226859331131
# 317.20970410108566
# 316.3777742087841
# 320.88949596881866
# 304.3649850487709
# 315.14572563767433
# 292.9787109196186
# 294.8200542330742
# 211.52833104133606
# 318.8966282606125
# 317.78890603780746
# 317.72331580519676
# 318.3593574464321
# 319.58338740468025
# 313.16482576727867
# 307.63268637657166
# 317.5193777382374
# 316.5977131128311
# 317.7485427558422
# 313.1338657438755
# 312.1658820807934
# 312.2010041475296
# 312.31078267097473
# 298.20522779226303
# 297.7501700222492
# 299.8660623729229
# 298.74881476163864
# 298.91380167007446
# 298.271660476923
# 298.25644731521606
# 296.75729727745056
# 304.3433373272419
# 301.64340928196907
# 298.2199894487858
# 299.56973335146904
# 298.4386273622513
# 300.2606011033058
# 298.75166949629784
# 299.6829253733158
# 296.50356006622314
# 298.0566326379776
# 299.06960359215736
# 297.7801043689251
# 304.42606070637703
# 306.43733873963356
# 297.9131255745888
# 298.8552657067776
# 298.3858554363251
# 298.05604776740074
# 296.3089570701122
# 296.5184573531151
# 305.91039937734604
# 306.2628698647022
# 299.37552428245544
# 299.0505233705044
# 300.0171172618866
# 288.0526269674301
# 319.44545409083366
# 319.92088881134987
# 320.6040249466896
# 314.54071521759033
# 314.7206415235996
# 317.01895383000374
# 318.3892026543617
# 323.69296726584435
# 319.3192789852619
# 320.514954328537
# 320.6974419951439
# 297.5435939133167
# 322.26688918471336
# 311.0389794409275
# 325.5393042564392
# 295.4372422993183
# 319.46174865961075
# 297.6489208638668
# 320.34983226656914
# 320.8743707239628
# 318.3397474884987
# 317.9539857506752
# 317.97352063655853
# 317.81616044044495
# 318.46852469444275
# 294.3315947651863
# 232.42720246315002
# 213.69492211937904
# 222.51662036776543
# 238.09209513664246
# 228.70346626639366
# 240.13024073839188
# 252.6733414232731
# 258.00349605083466
# 261.3970272541046
# 346.6074866056442
# 251.57896384596825
# 328.8283565938473
# 193.66918247938156
# 200.2100169956684
# 277.86036241054535
# 241.71883350610733
# 250.18284153938293
# 226.39590528607368
# 221.30966839194298
# 317.3036784827709
# 297.6013134717941
# 219.5848105251789
# 218.3872130215168
# 291.6430113017559
# 299.4120381474495
