# %%
# %pylab inline

import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('ticks')
sns.set_context('paper')

from matplotlib.colors import LogNorm

from glob import glob
import os, sys, pickle, requests
from sklearn.metrics import r2_score
from arnie.free_energy import free_energy
from arnie.mfe import mfe

from scipy.stats import pearsonr, spearmanr

def corrfunc(x,y, ax=None, **kws):
    r, pval = spearmanr(x, y)
    ax = ax or plt.gca()    
    m, b = np.poly1d(np.polyfit(x, y, 1))
    xmin, xmax = ax.get_xlim()
    plt.plot([xmin,xmax],[xmin*m+b,xmax*m+b],c='k',linestyle=':')
    ax.set_xlim([xmin,xmax])
    rho = '\u03C1'
    ax.annotate(f'R:{r:.2f}', xy=(.65, .9), xycoords=ax.transAxes)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('collated_predictions_233x_07Jul2021.csv')
df['k_deg_full_length_normalize'] = df['k_deg_per_hour']/df['length']
df_filter = df.loc[df['single_exp_fit_ok']==1][df['k_deg_per_hour'] > 0]

df_filter = df_filter.loc[df_filter['Expt type']!='COV2 Eterna']
df_filter = df_filter.loc[df_filter['k_deg_err_per_hour'] < 0.15] 

#df_filter = df_filter.loc[df_filter.Barcode!='820117B1'] #outlier for barna lab pred

# %%
np.percentile(df_filter['k_deg_err_per_hour'], 98)
# Out:
# 0.12646364000000046

# %%
sns.swarmplot(x='Expt type', y='k_deg_err_per_hour', data=df_filter)
# Out:
# /Users/hwayment/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 7.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Expt type', ylabel='k_deg_err_per_hour'>

# %%
sns.scatterplot(x='k_deg_normalize', y='RT_PCR_length', data=df_filter, hue='Expt type')
# Out:
# <AxesSubplot:xlabel='k_deg_normalize', ylabel='RT_PCR_length'>

# %%
sns.swarmplot(x='Expt type', y='k_deg_normalize', data=df_filter)
# Out:
# /Users/hwayment/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Expt type', ylabel='k_deg_normalize'>

# %%
predictor_list = ['Vienna', 'EternaFold', 'DegScore2.1', 'nullrecurrent','kazuki2', 'nr_k2_ensembled']

def rmse(x, y):
    return np.sqrt(np.mean(np.square(x-y)))

figure(figsize=(8,4))

nrows, ncols=2,3
for i, k in enumerate(predictor_list):
    subplot(nrows, ncols,i+1)
    
    r2 = rmse(df_filter['SUP %s PCR' % k],df_filter['k_deg_per_hour'])
    C = np.corrcoef(df_filter['SUP %s PCR' % k],df_filter['k_deg_per_hour'])[0][1]
    
    errorbar(df_filter['k_deg_per_hour'], df_filter['SUP %s PCR'% k], xerr = df_filter['k_deg_err_per_hour'],fmt='.', color='k', zorder=0, markersize=0 )
    sns.scatterplot(x='k_deg_per_hour', y='SUP %s PCR'% k, hue='Expt type', data = df_filter, linewidth=0)
    title("%s: R=%.2f" % (k,C))
    #xlim([0,0.0015])
    #ylim([0,0.7])
    if i!=2:
        legend([],frameon=False)
    else:
        legend(bbox_to_anchor=(1,1),frameon=False)
        
tight_layout()
#savefig('scatterplot_233x_AUP_dec16.pdf', bbox_inches='tight')

# %%
predictor_list = ['Vienna', 'EternaFold', 'DegScore2.1', 'nullrecurrent','kazuki2', 'nr_k2_ensembled']

def rmse(x, y):
    return np.sqrt(np.mean(np.square(x-y)))

figure(figsize=(8,4))

nrows, ncols=2,3
for i, k in enumerate(predictor_list):
    subplot(nrows, ncols,i+1)

    errorbar(df_filter['k_deg_normalize'], df_filter['AUP %s PCR'% k], xerr = df_filter['k_deg_err_normalize'],fmt='.', color='k', zorder=0, markersize=0 )
    sns.scatterplot(x='k_deg_normalize', y='AUP %s PCR'% k, hue='Expt type', data = df_filter, linewidth=0)
    title(k)
    xlim([0,0.0015])

    corrfunc(df_filter['k_deg_normalize'], df_filter['AUP %s PCR'% k])
    #ylim([0,0.7])
    if i!=2:
        legend([],frameon=False)
    else:
        legend(bbox_to_anchor=(1,1),frameon=False)
    
    
tight_layout()
savefig('scatterplot_233x_07Jul2021_w_ensemble.pdf', bbox_inches='tight')
savefig('scatterplot_233x_07Jul2021_w_ensemble.png', dpi=300, bbox_inches='tight')

# %%
df_filter['half_life'] = np.log(2)/df_filter['k_deg_per_hour']
df_filter['half_life_err'] = df_filter['half_life']*df_filter['k_deg_err_per_hour']/df_filter['k_deg_per_hour']
df_filter['half_life_normalize'] = df_filter['half_life']*df_filter['RT_PCR_length']
df_filter['half_life_err_normalize'] = df_filter['half_life_err']*df_filter['RT_PCR_length']

# %%
df_filter.groupby('Expt type').size()
# Out:
# Expt type
# MEV                 9
# NLuc Barna lab    101
# NLuc Eterna        65
# eGFP               13
# dtype: int64

# %%
df_filter.keys()
# Out:
# Index(['Barcode', 'Human readable name', 'Expt type', 'k_deg_per_hour',
#        'k_deg_err_per_hour', 'single_exp_fit_ok', 'RT_PCR_start_pos',
#        'RT_PCR_end_pos', 'RNA_sequence', 'RT_PCR_length', 'k_deg_normalize',
#        'k_deg_err_normalize', 'length', 'SUP DegScore2.1 FULL',
#        'SUP DegScore2.1 PCR', 'SUP Vienna FULL', 'SUP Vienna PCR',
#        'SUP EternaFold FULL', 'SUP EternaFold PCR', 'SUP nullrecurrent FULL',
#        'SUP nullrecurrent PCR', 'SUP kazuki2 FULL', 'SUP kazuki2 PCR',
#        'SUP Tunguz FULL', 'SUP Tunguz PCR', 'SUP nr_k2_ensembled FULL',
#        'SUP nr_k2_ensembled PCR', 'AUP Vienna PCR', 'AUP Vienna FULL',
#        'AUP EternaFold PCR', 'AUP EternaFold FULL', 'AUP DegScore2.1 PCR',
#        'AUP DegScore2.1 FULL', 'AUP Tunguz PCR', 'AUP Tunguz FULL',
#        'AUP nullrecurrent PCR', 'AUP nullrecurrent FULL', 'AUP kazuki2 PCR',
#        'AUP kazuki2 FULL', 'AUP nr_k2_ensembled PCR',
# ...

# %%
predictor_list = ['EternaFold', 'DegScore2.1', 
                  'Tunguz','nullrecurrent','kazuki2']

labels = ['p(unpaired)', 'DegScore (Leppek, 2021)', 'DegScore-XGBoost', 'Kaggle 1st (nullrecurrent)','Kaggle 2nd (kazuki2)']
def rmse(x, y):
    return np.sqrt(np.mean(np.square(x-y)))

figure(figsize=(12,2))

nrows, ncols= 1,5
for i, k in enumerate(predictor_list):
    subplot(nrows, ncols,i+1)

    errorbar(df_filter['half_life_normalize'], df_filter['AUP %s PCR'% k], xerr = df_filter['half_life_err_normalize'],fmt='.', color='k', zorder=0, markersize=0 )
    sns.scatterplot(x='half_life_normalize', y='AUP %s PCR'% k, hue='Expt type', data = df_filter, linewidth=0)
    sns.scatterplot(x='half_life_normalize', y='AUP %s PCR'% k, data = df_filter.loc[df_filter['Human readable name'].str.contains('Yellowstone')], edgecolor='k', marker='*',color='red', s=150,zorder=10)
    sns.scatterplot(x='half_life_normalize', y='AUP %s PCR'% k, data = df_filter.loc[df_filter['Human readable name'].str.contains('jiabei')], edgecolor='k', marker='*',color='red', s=150,zorder=10)
    
    ylabel(labels[i])
    #xlim([0,0.0015])
    #xticks([0,0.0005, 0.001,0.0015], ['0','0.5', '1','1.5'])

    corrfunc(df_filter['half_life_normalize'], df_filter['AUP %s PCR'% k])
    #ylim([0,0.7])
    xlabel('Half life per nt (hr)')
    if i!=4:
        legend([],frameon=False)
    else:
        legend(bbox_to_anchor=(1,1),frameon=False)
    

tight_layout()
savefig('scatterplot_half_lives_233x_24Sep2021.pdf', bbox_inches='tight')
savefig('scatterplot_half_lives_233x_24Sep2021.png', dpi=300, bbox_inches='tight')

# %%
! open -a "Adobe Illustrator" example_yellowstone_prediction_gist_heat_r.pdf

# %%
predictor_list = ['EternaFold', 'DegScore2.1', 'nullrecurrent','kazuki2']

labels = ['p(unpaired)', 'DegScore (Leppek, 2021)', 'Kaggle 1st (nullrecurrent)','Kaggle 2nd (kazuki2)']
def rmse(x, y):
    return np.sqrt(np.mean(np.square(x-y)))

figure(figsize=(10,2))

nrows, ncols= 1,4
for i, k in enumerate(predictor_list):
    subplot(nrows, ncols,i+1)

    errorbar(df_filter['k_deg_normalize'], df_filter['AUP %s PCR'% k], xerr = df_filter['k_deg_err_normalize'],fmt='.', color='k', zorder=0, markersize=0 )
    sns.scatterplot(x='k_deg_normalize', y='AUP %s PCR'% k, hue='Expt type', data = df_filter, linewidth=0)
    ylabel(labels[i])
    xlim([0,0.0015])
    xticks([0,0.0005, 0.001,0.0015], ['0','0.5', '1','1.5'])

    corrfunc(df_filter['k_deg_normalize'], df_filter['AUP %s PCR'% k])
    #ylim([0,0.7])
    xlabel('Deg. rate per nt (1e-3 hr$^{-1}$)')
    if i!=3:
        legend([],frameon=False)
    else:
        legend(bbox_to_anchor=(1,1),frameon=False)
    

tight_layout()
savefig('scatterplot_233x_07Jul2021.pdf', bbox_inches='tight')
savefig('scatterplot_233x_07Jul2021.png', dpi=300, bbox_inches='tight')

# %%
predictor_list = ['Vienna', 'EternaFold', 'DegScore2.1', 'Tunguz', 'nullrecurrent','kazuki2', 'nr_k2_ensembled']

def rmse(x, y):
    return np.sqrt(np.mean(np.square(x-y)))

figure(figsize=(12,4))

nrows, ncols=2,4
for i, k in enumerate(predictor_list):
    subplot(nrows, ncols,i+1)

    sns.scatterplot(x='k_deg_full_length_normalize', y='AUP %s FULL'% k, hue='Expt type', data = df_filter, linewidth=0)
    title(k)
    xlim([0,0.0015])

    corrfunc(df_filter['k_deg_full_length_normalize'], df_filter['AUP %s FULL'% k])
    #ylim([0,0.7])
    if i!=3:
        legend([],frameon=False)
    else:
        legend(bbox_to_anchor=(1,1),frameon=False)
    
    
tight_layout()
savefig('scatterplot_233x_07Jul2021_w_ensemble.pdf', bbox_inches='tight')
savefig('scatterplot_233x_07Jul2021_w_ensemble.png', dpi=300, bbox_inches='tight')

# %%
len(df_filter.loc[df_filter['Human readable name'].str.contains('Yellowstone')]['RNA_sequence'].values[0])
# Out:
# 928

# %%
tmp = np.loadtxt('../hkws_fix_Nullrecurrent_jun2021/flat_FULL_233x.csv',delimiter=',')
example_vec = tmp[109]


imshow(example_vec[:928].reshape(1,-1), aspect=50, cmap='gist_heat_r')
yticks([])
savefig('example_yellowstone_prediction_gist_heat_r.pdf',bbox_inches='tight')

# %%
np.random.normal([0,0,0],[1,1,1])
# Out:
# array([ 0.94055105, -0.70560741, -1.11326268])

# %%
r_list=[]
for _ in range(100):
    tmp = df_filter.sample(frac=1)
    
    resampled_kdegs = np.random.normal(list(tmp['k_deg_per_hour'].values), list(tmp['k_deg_err_per_hour'].values))
    
    r, p = spearmanr(tmp['half_life'], resampled_kdegs)
    r_list.append(r)
                     
np.mean(r_list)
# Out:
# -0.9469598903391142

# %%
predictor_list = ['Vienna', 'EternaFold', 'DegScore2.1', 'nullrecurrent','kazuki2', 'nr_k2_ensembled']

def rmse(x, y):
    return np.sqrt(np.mean(np.square(x-y)))

figure(figsize=(20,20))

nrows, ncols=4,6
for j, const in enumerate(df_filter['Expt type'].unique()):

    for i, k in enumerate(predictor_list):
        subplot(nrows, ncols,j*6+i+1)
        tmp = df_filter.loc[df_filter['Expt type']==const]
        #tmp = tmp.loc[tmp.Barcode!='820117B1'] #outlier for barna lab pred
        #if const=='NLuc Barna lab': print(tmp.sort_values('SUP %s PCR' % k).iloc[-1])
        r2 = rmse(tmp['SUP %s PCR' % k],tmp['k_deg_per_hour'])
        C = np.corrcoef(tmp['SUP %s PCR' % k],tmp['k_deg_per_hour'])[0][1]

        errorbar(tmp['k_deg_per_hour'], tmp['SUP %s PCR'% k], xerr = tmp['k_deg_err_per_hour'],fmt='.', color='k', zorder=0, markersize=0 )
        sns.scatterplot(x='k_deg_per_hour', y='SUP %s PCR'% k, hue='Expt type', data = tmp, linewidth=0)
        title("%s: R=%.2f" % (k,C))

#         if i!=2:
#             legend([],frameon=False)
#         else:
#             legend(bbox_to_anchor=(1,1),frameon=False)

tight_layout()
#savefig('scatterplot_233x_AUP_dec16.pdf', bbox_inches='tight')

# %%
corr_df = pd.DataFrame()
corr_df_norm = pd.DataFrame()

for typ2 in ['FULL','PCR']:
    for pred in predictor_list:
        r, _ = pearsonr(df_filter["SUP %s %s" % (pred, typ2)], df_filter['k_deg_per_hour'])
        corr_df = corr_df.append({'Region':typ2, 'Pearson R': r,'Predictor':pred},ignore_index=True)
        
        if typ2=='FULL':
            r, _ = pearsonr(df_filter["AUP %s %s" % (pred, typ2)], df_filter['k_deg_full_length_normalize'])
        else:
            r, _ = pearsonr(df_filter["AUP %s %s" % (pred, typ2)], df_filter['k_deg_normalize'])

        corr_df_norm = corr_df_norm.append({'Region':typ2, 'Pearson R': r,'Predictor':pred},ignore_index=True)
        
figure(figsize=(6,3))

subplot(1,2,1)
sns.barplot(x='Region',y='Pearson R', data=corr_df, hue='Predictor')
ylim([0,1])
legend([],frameon=False)

subplot(1,2,2)

sns.barplot(x='Region',y='Pearson R', data=corr_df_norm, hue='Predictor')
ylim([0,1])
legend(title='Predictor', frameon=False)


tight_layout()

# %%
corr_df_norm = pd.DataFrame()
for typ2 in ['FULL','PCR']:
    for pred in predictor_list:
        r, _ = pearsonr(df_filter["AUP %s %s" % (pred, typ2)], df_filter['k_deg_normalize'])
        corr_df_norm = corr_df_norm.append({'Region':typ2, 'Pearson R': r,'Predictor':pred},ignore_index=True)
        
sns.barplot(x='Region',y='Pearson R', data=corr_df_norm, hue='Predictor')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Pearson R'>
